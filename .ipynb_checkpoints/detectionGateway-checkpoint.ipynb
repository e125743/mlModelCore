# %%
# !pip install firebase-admin
# Out:
# Collecting firebase-admin
#   Downloading firebase_admin-7.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting cachecontrol>=0.14.3 (from firebase-admin)
#   Downloading cachecontrol-0.14.4-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.25.1 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.29.0)
# Collecting google-cloud-firestore>=2.21.0 (from firebase-admin)
#   Downloading google_cloud_firestore-2.23.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: google-cloud-storage>=3.1.1 in /opt/conda/lib/python3.10/site-packages (from firebase-admin) (3.8.0)
# Collecting pyjwt>=2.10.1 (from pyjwt[crypto]>=2.10.1->firebase-admin)
#   Downloading pyjwt-2.11.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: httpx==0.28.1 in /opt/conda/lib/python3.10/site-packages (from httpx[http2]==0.28.1->firebase-admin) (0.28.1)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (4.12.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (3.11)
# Requirement already satisfied: h2<5,>=3 in /opt/conda/lib/python3.10/site-packages (from httpx[http2]==0.28.1->firebase-admin) (4.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (6.33.4)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.27.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.47.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.76.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (4.9.1)
# Requirement already satisfied: typing-extensions~=4.12 in /opt/conda/lib/python3.10/site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (4.15.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /opt/conda/lib/python3.10/site-packages (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /opt/conda/lib/python3.10/site-packages (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin) (4.1.0)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.6.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (0.6.2)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /opt/conda/lib/python3.10/site-packages (from cachecontrol>=0.14.3->firebase-admin) (1.1.2)
# Requirement already satisfied: google-cloud-core<3.0.0,>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-firestore>=2.21.0->firebase-admin) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage>=3.1.1->firebase-admin) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage>=3.1.1->firebase-admin) (1.8.0)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/conda/lib/python3.10/site-packages (from pyjwt[crypto]>=2.10.1->firebase-admin) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase-admin) (2.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase-admin) (2.22)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (1.3.1)
# Downloading firebase_admin-7.2.0-py3-none-any.whl (138 kB)
# Downloading cachecontrol-0.14.4-py3-none-any.whl (22 kB)
# Downloading google_cloud_firestore-2.23.0-py3-none-any.whl (411 kB)
# Downloading pyjwt-2.11.0-py3-none-any.whl (28 kB)
# Installing collected packages: pyjwt, cachecontrol, google-cloud-firestore, firebase-admin
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [firebase-admin]m [google-cloud-firestore]
# Successfully installed cachecontrol-0.14.4 firebase-admin-7.2.0 google-cloud-firestore-2.23.0 pyjwt-2.11.0

# %%
# !pip install --upgrade google-cloud-pubsub
# Out:
# Collecting google-cloud-pubsub
#   Downloading google_cloud_pubsub-2.35.0-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: grpcio<2.0.0,>=1.51.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsub) (1.76.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsub) (2.47.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.29.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsub) (1.27.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsub) (6.33.4)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsub) (0.14.3)
# Requirement already satisfied: grpcio-status>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsub) (1.76.0)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsub) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsub) (1.39.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.32.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (4.9.1)
# Requirement already satisfied: typing-extensions~=4.12 in /opt/conda/lib/python3.10/site-packages (from grpcio<2.0.0,>=1.51.3->google-cloud-pubsub) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (0.6.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-api>=1.27.0->google-cloud-pubsub) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.27.0->google-cloud-pubsub) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-sdk>=1.27.0->google-cloud-pubsub) (0.60b1)
# Downloading google_cloud_pubsub-2.35.0-py3-none-any.whl (320 kB)
# Installing collected packages: google-cloud-pubsub
# Successfully installed google-cloud-pubsub-2.35.0

# %%
# from google.cloud import pubsub_v1

# project_id = "myproducts-488109"
# subscription_id = "my-sub"

# subscriber = pubsub_v1.SubscriberClient()
# subscription_path = subscriber.subscription_path(project_id, subscription_id)

# # 最大 N 件ずつ pull
# response = subscriber.pull(
#     request={
#         "subscription": subscription_path,
#         "max_messages": 100
#     }
# )

# for received_message in response.received_messages:
#     print(f"Message: {received_message.message.data.decode('utf-8')}")
    # ACK を返す（消さないならここで処理のみ）
    # subscriber.acknowledge(
    #     request={
    #         "subscription": subscription_path,
    #         "ack_ids": [received_message.ack_id],
    #     }
    # )

# %%
import os
import shutil

down_fol = 'origineImages'
up_fol = 'detectedImages'

for fol_ in [down_fol, up_fol]:
    if os.path.exists(f'./{fol_}'):
        shutil.rmtree(f'./{fol_}')
    os.mkdir(f'./{fol_}')

# %%
import firebase_admin
from firebase_admin import credentials, storage
from glob import glob

if not firebase_admin._apps:
    # cred = credentials.Certificate(glob('./seacrets/*-firebase-adminsdk-*.json')[0])
    firebase_admin.initialize_app(#cred, 
        options={"storageBucket": "myproducts-488109.firebasestorage.app"}
    )
bucket = storage.bucket()

# %%
from ultralytics import YOLO
from ultralytics.utils.plotting import Colors

model = YOLO('yolov8n.pt')

# %%
blob = bucket.blob(f'{down_fol}/ATfCyM3WVHe8UhaFwkyN.jpg')
blob.download_to_filename(f'./{down_fol}/ATfCyM3WVHe8UhaFwkyN.jpg')

results = model(f'./{down_fol}/ATfCyM3WVHe8UhaFwkyN.jpg',save=True)
results[0].save(f'./{up_fol}/ATfCyM3WVHe8UhaFwkyN.jpg')

labels = []
labelColors = []
colors = Colors()  # 公式パレット
for box in results[0].boxes:
    class_id = int(box.cls.item())
    cla_name = model.names[class_id]
    color = colors(class_id)  # ← これが描画に使われる色
    print("class:", class_id,',', cla_name, "RGB:", color)
    r,g,b = color
    labelColor = "#{:02x}{:02x}{:02x}".format(r,g,b)
    print(labelColor)
    labels.append(cla_name)
    labelColors.append(labelColor)
print(labels)
print(labelColors)
# Out:
# image 1/1 /home/jupyter/mlModelCore/origineImages/ATfCyM3WVHe8UhaFwkyN.jpg: 640x640 1 person, 1 train, 1 truck, 365.9ms
# Speed: 15.6ms preprocess, 365.9ms inference, 33.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /home/jupyter/mlModelCore/runs/detect/predict6
# class: 6 , train RGB: (255, 68, 79)
# #ff444f
# class: 0 , person RGB: (4, 42, 255)
# #042aff
# class: 7 , truck RGB: (204, 237, 0)
# #cced00
# ['train', 'person', 'truck']
# ['#ff444f', '#042aff', '#cced00']

# %%
# from datetime import datetime
# from zoneinfo import ZoneInfo

# now = datetime.now(ZoneInfo("Asia/Tokyo"))
# print(now)
# Out:
# 2026-03-02 20:39:52.269523+09:00
