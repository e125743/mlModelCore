# %%
#! pip install ultralytics

# %%
#! pip install pycocotools

# %%
#! gcloud storage cp gs://machien-learning-prot-type/annotations.zip ./annotations.zip

# %%
#! unzip annotations.zip

# %%
####ここから、サンプルデータを取得

# %%
# from pycocotools.coco import COCO
# import requests, os, random

# # COCO annotationファイル
# ann_file = 'annotations/instances_val2017.json'
# coco = COCO(ann_file)

# %%
# # カテゴリID取得
# cat_ids = coco.getCatIds()

# # カテゴリ情報取得
# cats = coco.loadCats(cat_ids)

# # ラベル名だけ一覧表示
# names = [cat['name'] for cat in cats]
# print(names)


# dir_ = 'cocoImages'
# if os.path.isdir(dir_) != True:
#     os.mkdir(dir_)

# %%
# sample_num = 5
# for n_ in names:
#     print('getImages:',n_)
#     # personカテゴリ取得
#     cat_ids = coco.getCatIds(catNms=[n_])
#     img_ids = coco.getImgIds(catIds=cat_ids)
    
#     # ランダムに選ぶ
#     selected = random.sample(img_ids, sample_num)
    
#     if os.path.isdir(dir_+'/'+n_) != True:
#         os.mkdir(dir_+'/'+n_)
    
#     for img_id in selected:
#         img = coco.loadImgs(img_id)[0]
#         url = img['coco_url']
#         img_data = requests.get(url).content
#         with open(f"{dir_}/{n_}/{img['file_name']}", "wb") as f:
#             f.write(img_data)

# print("Done")

# %%
### ここから、画像をYOLOに掛けていく

# %%
from ultralytics import YOLO
from ultralytics.utils.plotting import Colors

# Load a model
model = YOLO('yolov8n.pt')

# %%
results = model('../cocoImages/bus/000000373353.jpg',save=True)

results[0].save('../out.jpg')
# Out:
# image 1/1 /home/jupyter/mlModelCore/../cocoImages/bus/000000373353.jpg: 448x640 6 persons, 21 cars, 1 bus, 384.5ms
# Speed: 23.4ms preprocess, 384.5ms inference, 5.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /home/jupyter/mlModelCore/runs/detect/predict
# '../out.jpg'

# %%
colors = Colors()  # 公式パレット
for box in results[0].boxes:
    class_id = int(box.cls.item())
    cla_name = model.names[class_id]
    color = colors(class_id)  # ← これが描画に使われる色
    print("class:", class_id,',', cla_name, "RGB:", color)
# Out:
# class: 0 , person RGB: (4, 42, 255)
# class: 2 , car RGB: (243, 243, 243)
# class: 5 , bus RGB: (255, 111, 221)
# class: 2 , car RGB: (243, 243, 243)
# class: 2 , car RGB: (243, 243, 243)
# class: 2 , car RGB: (243, 243, 243)
# class: 0 , person RGB: (4, 42, 255)
# class: 0 , person RGB: (4, 42, 255)
# class: 2 , car RGB: (243, 243, 243)
# class: 0 , person RGB: (4, 42, 255)
# class: 0 , person RGB: (4, 42, 255)
# class: 2 , car RGB: (243, 243, 243)
# class: 0 , person RGB: (4, 42, 255)
# class: 2 , car RGB: (243, 243, 243)
# class: 2 , car RGB: (243, 243, 243)
# class: 2 , car RGB: (243, 243, 243)
# class: 2 , car RGB: (243, 243, 243)
# class: 2 , car RGB: (243, 243, 243)
# class: 2 , car RGB: (243, 243, 243)
# class: 2 , car RGB: (243, 243, 243)
# class: 2 , car RGB: (243, 243, 243)
# class: 2 , car RGB: (243, 243, 243)
# class: 2 , car RGB: (243, 243, 243)
# class: 2 , car RGB: (243, 243, 243)
# class: 2 , car RGB: (243, 243, 243)
# class: 2 , car RGB: (243, 243, 243)
# ...
